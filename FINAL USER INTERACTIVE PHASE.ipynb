# %%
file_path = r"C:\Users\NEW USER\Downloads\OLAPCPPROJECT\heart_failure_clinical_records_dataset-pcp.csv"

# %%
import FINAL_PCP_ASSIGNMENT_WORK_PHASE

# %%
 from FINAL_PCP_ASSIGNMENT_WORK_PHASE import interactive_module, load_data, compute_avg_modal_median_age_death, compute_average_time_for_survival, compute_age_statistic_high_blood_pressure,  compute_age_statistic_diabetes,diabetes_linked_to_smoking_and_hbp, compute_average_serum_sodium_with_diabetes, is_anaemia_linked_to_smoking, no_hbp_death, compute_iqrs,  compute_iqr, compute_sample_variances, compute_sample_variance

# %%
rows = load_data(file_path)

# %%
if __name__ == "__main__":
    interactive_module()
# Out:
# Welcome to the Interactive Module!
# 1. compute the average age, modal age, median age of those whose heart failure resulted in death
# 2. compute the average time taken for those whose heart failure did not result in death.
# 3. compute median age, average age, and modal age of those with high blood pressure.
# 4. compute the median age, average age, and modal age of those with diabetes.
# 5. determine whether diabetes is linked to smoking and high blood pressure.
# 6. Compute the average serum sodium of those with diabetes
# 7. Compute to determine if anaemia is linked to smoking or not.
# 8. Compute to returns anyone without high blood pressure that died of heart failure
# 9. Compute to returns the IQRs (Interquartile Range) of ejection fraction and serum creatinine
# 10. Compute to return the sample variance of creatinine phosphokinase and serum sodium.
# 0. Quit
# Enter your choice: 1
#
# Results:
# Average Age of death: 65.21528125
# Modal Age of death: 60.0
# ...
